# %%
import pandas as pd

# %%
melb_df = pd.read_csv('data/melb_data_fe.csv')
display(melb_df.head())
# Out:
#        Suburb  Rooms   Type      Price Method SellerG        Date  Distance  \
# 0  Abbotsford      2  house  1480000.0      S  Biggin  2016-03-12       2.5
# 1  Abbotsford      2  house  1035000.0      S  Biggin  2016-04-02       2.5
# 2  Abbotsford      3  house  1465000.0     SP  Biggin  2017-04-03       2.5
# 3  Abbotsford      3  house   850000.0     PI  Biggin  2017-04-03       2.5
# 4  Abbotsford      4  house  1600000.0     VB  Nelson  2016-04-06       2.5
#
#    Postcode  Bedroom  ...  Longtitude             Regionname  Propertycount  \
# 0      3067        2  ...    144.9984  Northern Metropolitan           4019
# 1      3067        2  ...    144.9934  Northern Metropolitan           4019
# 2      3067        3  ...    144.9944  Northern Metropolitan           4019
# 3      3067        3  ...    144.9969  Northern Metropolitan           4019
# 4      3067        3  ...    144.9941  Northern Metropolitan           4019
#
# ...

# %%
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  object
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  object
#  5   SellerG          13580 non-null  object
#  6   Date             13580 non-null  object
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  object
#  15  Lattitude        13580 non-null  float64
# ...

# %% [markdown]
# ### Задание 1.1

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'])
quarter_melb_df = melb_df['Date'].dt.quarter
print(quarter_melb_df)
display(quarter_melb_df.value_counts())
# Out:
# 0        1
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 13575    3
# 13576    3
# 13577    3
# 13578    3
# 13579    3
# Name: Date, Length: 13580, dtype: int32
# Date
# 3    4873
# 2    4359
# 4    2329
# 1    2019
# Name: count, dtype: int64

# %% [markdown]
# ### Задание 1.2

# %%
cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']
max_unique_count = 150
for col in melb_df.columns:
    if melb_df[col].nunique() < max_unique_count and col not in cols_to_exclude:
        melb_df[col] = melb_df[col].astype('category')
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %%
#Пример сортировки таблицы по цене
melb_df.sort_values(by='Price').head(10)
# Out:
#                Suburb  Rooms   Type     Price Method        SellerG  \
# 2652        Footscray      1   unit   85000.0     PI        Burnham
# 1805            other      4  house  131000.0     PI          other
# 7303           Albion      1   unit  145000.0     PI         Biggin
# 1927           Coburg      4  house  145000.0     PI         Jellis
# 7940         Hawthorn      1   unit  160000.0     VB            HAR
# 12666       Brunswick      1   unit  170000.0     VB         Nelson
# 8811        Footscray      1   unit  170000.0     PI        Burnham
# 7293           Albion      1   unit  185000.0      S  hockingstuart
# 8504   West Footscray      1   unit  185000.0     PI            Jas
# 7305           Albion      2   unit  190000.0     SP        Burnham
#
#             Date  Distance  Postcode  Bedroom  ...  Longtitude  \
# 2652  2016-03-09       6.4      3011        1  ...   144.89000
# 1805  2017-02-25       8.9      3162        4  ...   145.02420
# ...

# %%
#Пример сортировки таблицы по дате от самой последней к самой первой
melb_df.sort_values(by='Date', ascending=False)
# Out:
#              Suburb  Rooms   Type      Price Method    SellerG       Date  \
# 11144     Northcote      4  house  1955000.0     SP    McGrath 2017-12-08
# 11217  Surrey Hills      3  house  1775000.0     PI     Jellis 2017-12-08
# 11206      St Kilda      4  house  1600000.0     VB       Gary 2017-12-08
# 11207    Strathmore      7  house  2000000.0     SP     Nelson 2017-12-08
# 11208    Strathmore      4  house  1610000.0      S      other 2017-12-08
# ...             ...    ...    ...        ...    ...        ...        ...
# 1555     Camberwell      4  house  2650000.0      S     Jellis 2016-03-09
# 4510       Oak Park      3  house   892000.0      S     Nelson 2016-03-09
# 4388      Northcote      3  house  1200000.0      S     Nelson 2016-03-09
# 6184   Surrey Hills      3  house  1205000.0      S  Fletchers 2016-01-28
# 6183   Surrey Hills      2   unit   813000.0      S  Fletchers 2016-01-28
#
#        Distance  Postcode  Bedroom  ...  Longtitude             Regionname  \
# ...

# %%
#Сортировка таблицы по 2 значениям
melb_df.sort_values(by=['Distance', 'Price']).loc[::10, 
['Distance','Price']]
# Out:
#        Distance      Price
# 11428       0.0   387000.0
# 10512       0.7   600000.0
# 5727        1.2   485000.0
# 8671        1.2   595000.0
# 5736        1.2   740000.0
# ...         ...        ...
# 12011      38.0   680000.0
# 10673      38.0   810000.0
# 13429      38.0  1155000.0
# 11102      41.0   650000.0
# 12728      45.9   650000.0
#
# [1358 rows x 2 columns]

# %%
#Изменение порядка следования сортирвоки столбцов
melb_df.sort_values(by=['Price', 'Distance']).loc[::10, 
['Price', 'Distance']]
# Out:
#            Price  Distance
# 2652     85000.0       6.4
# 7116    200000.0       7.8
# 5206    220000.0      11.2
# 7240    241000.0       8.2
# 2898    250000.0      13.0
# ...          ...       ...
# 13341  4060000.0       6.3
# 8591   4275000.0       1.5
# 1094   4700000.0      11.2
# 5801   5046000.0       6.1
# 251    5525000.0       6.3
#
# [1358 rows x 2 columns]

# %%
#Сортировка и фильтрация вместе
mask1 = melb_df['AreaRatio'] < -0.8
mask2 = melb_df['Type'] == 'townhouse'
mask3 = melb_df['SellerG'] == 'McGrath'
melb_df[mask1 & mask2 & mask3].sort_values(
    by=['Date', 'AreaRatio'],
    ascending=[True, False],
    ignore_index=True
).loc[:, ['Date', 'AreaRatio']]
# Out:
#         Date  AreaRatio
# 0 2016-07-26  -0.974922
# 1 2016-09-24  -0.971831
# 2 2016-11-27  -0.953608
# 3 2016-12-11  -0.945946
# 4 2017-08-04  -0.947368
# 5 2017-08-04  -0.970874

# %% [markdown]
# ### Задание 2.2

# %%
melb_df.sort_values(
    by=['AreaRatio'],
    ignore_index=True
).loc[1557,['AreaRatio', 'BuildingArea']]
# Out:
# AreaRatio      -0.719689
# BuildingArea       126.0
# Name: 1557, dtype: object

# %% [markdown]
# ### Задание 2.3

# %%
mask1 = melb_df['Type'] == 'townhouse'
mask2 = melb_df['Rooms'] > 2
melb_df[mask1 & mask2].sort_values(
    by=['Rooms', 'MeanRoomsSquare'],
    ascending=[True, False],
    ignore_index=True
).loc[18,['Price']]
# Out:
# Price    1300000.0
# Name: 18, dtype: object

# %% [markdown]
# ### GroupBy

# %%
#Применим агрегирующую функцию соеднего к результату работы groupby()
melb_df.groupby(by='Type').mean(numeric_only=True)
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_3272\3763697465.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(by='Type').mean(numeric_only=True)
#               Rooms         Price   Distance     Postcode   Bedroom  Bathroom  \
# Type
# house      3.260874  1.242665e+06  10.979479  3104.080643  3.229336  1.613822
# townhouse  2.837522  9.337351e+05   9.851346  3100.777379  2.814183  1.809695
# unit       1.963871  6.051275e+05   7.607391  3110.797481  1.966523  1.183295
#
#                 Car    Landsize  BuildingArea  Lattitude  Longtitude  \
# Type
# house      1.772674  617.181924    152.162553 -37.803795  144.994700
# townhouse  1.555655  279.606822    134.649710 -37.815782  144.996489
# unit       1.128936  477.314219    102.235863 -37.823710  144.996363
#
# ...

# %%
#Применим метод только дня нахождения средней цены
melb_df.groupby(by='Type')['Price'].mean()
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_3272\1408585642.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(by='Type')['Price'].mean()
# Type
# house        1.242665e+06
# townhouse    9.337351e+05
# unit         6.051275e+05
# Name: Price, dtype: float64

# %%
#Выясним какие регионы наиболее удалены от центра Мельбурна
(melb_df.groupby(by='Regionname')
 ['Distance'].min().sort_values(ascending=False))
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_3272\4187081209.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (melb_df.groupby(by='Regionname')
# Regionname
# Western Victoria              29.8
# Eastern Victoria              25.2
# Northern Victoria             21.8
# South-Eastern Metropolitan    14.7
# Eastern Metropolitan           7.8
# Western Metropolitan           4.3
# Southern Metropolitan          0.7
# Northern Metropolitan          0.0
# Name: Distance, dtype: float64

# %%
#Строим таблицу для анализа продаж по месяцам
melb_df.groupby(by='MonthSale')['Price'].agg(
['count', 'mean', 'max']
).sort_values(by='count', ascending=False)
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_3272\1823068266.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(by='MonthSale')['Price'].agg(
#            count          mean        max
# MonthSale
# 8           1850  1.056371e+06  6500000.0
# 7           1835  9.314698e+05  9000000.0
# 5           1644  1.097807e+06  8000000.0
# 6           1469  1.068981e+06  7650000.0
# 3           1408  1.146762e+06  5600000.0
# 4           1246  1.050479e+06  5500000.0
# 9           1188  1.126349e+06  6400000.0
# 10           854  1.135970e+06  6250000.0
# 11           750  1.142503e+06  5050000.0
# 12           725  1.144737e+06  5700000.0
# 2            333  1.169051e+06  4735000.0
# 1            278  9.397921e+05  5200000.0

# %%
#Для получения полной информации обо всех статестических характеристик
melb_df.groupby('MonthSale')['Price'].agg('describe')
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_3272\811503802.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('MonthSale')['Price'].agg('describe')
#             count          mean            std       min       25%        50%  \
# MonthSale
# 1           278.0  9.397921e+05  577668.924214  170000.0  570500.0   795000.0
# 2           333.0  1.169051e+06  671564.357417  131000.0  710000.0  1020000.0
# 3          1408.0  1.146762e+06  709573.596867   85000.0  680000.0   945000.0
# 4          1246.0  1.050479e+06  591892.902979  145000.0  655000.0   905500.0
# 5          1644.0  1.097807e+06  668492.867996  145000.0  650000.0   905000.0
# 6          1469.0  1.068981e+06  606010.069052  222000.0  660000.0   900000.0
# ...

# %%
#Вычислим число уникальных риелторсих компаний в зависимости от региона
melb_df.groupby(by='Regionname')['SellerG'].agg(
    ['nunique', set]
)
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_3272\1655759248.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(by='Regionname')['SellerG'].agg(
#                             nunique  \
# Regionname
# Eastern Metropolitan             26
# Eastern Victoria                 11
# Northern Metropolitan            40
# Northern Victoria                11
# South-Eastern Metropolitan       25
# Southern Metropolitan            38
# Western Metropolitan             34
# Western Victoria                  6
#
#                                                                           set
# Regionname
# Eastern Metropolitan        {Noel, other, Miles, Biggin, Buxton, hockingst...
# Eastern Victoria            {other, O'Brien, Ray, Barry, Harcourts, Fletch...
# ...

# %% [markdown]
# ### Задание 3.1

# %%
melb_df.groupby(by='Rooms')['Price'].mean().sort_values(ascending=False)
# Out:
# Rooms
# 7     1.920700e+06
# 5     1.870260e+06
# 6     1.849366e+06
# 8     1.602750e+06
# 4     1.445282e+06
# 3     1.076081e+06
# 10    9.000000e+05
# 2     7.750812e+05
# 1     4.338245e+05
# Name: Price, dtype: float64

# %% [markdown]
# ### Задание 3.2

# %%
melb_df.groupby(by='Regionname')['Lattitude'].std().sort_values()
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_3272\2114338460.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(by='Regionname')['Lattitude'].std().sort_values()
# Regionname
# Western Victoria              0.011579
# Southern Metropolitan         0.043080
# Eastern Metropolitan          0.047890
# Northern Metropolitan         0.049639
# Western Metropolitan          0.051251
# South-Eastern Metropolitan    0.073411
# Northern Victoria             0.084455
# Eastern Victoria              0.147067
# Name: Lattitude, dtype: float64

# %% [markdown]
# ### Задание 3.3

# %%
mask1 = (melb_df['Date'] >= '2017-05-01')&(melb_df['Date'] <= '2017-09-01')
melb_df[mask1].groupby(by='SellerG')['Price'].sum().sort_values()
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_3272\1677028553.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df[mask1].groupby(by='SellerG')['Price'].sum().sort_values()
# SellerG
# LITTLE             2742000.0
# Cayzer             4439000.0
# Burnham            4550500.0
# Moonee             7328000.0
# Thomson            8332000.0
# Bells              8656000.0
# Alexkarbon        10985000.0
# McDonald          14637500.0
# Rendina           15422276.0
# Nick              16890000.0
# Douglas           18341000.0
# Buckingham        19033000.0
# C21               19515000.0
# Eview             19791500.0
# Collins           20217000.0
# Philip            22051800.0
# Chisholm          23225000.0
# Williams          23297000.0
# Love              23365500.0
# ...

# %% [markdown]
# ### Сводные таблицы

# %%
#Строим таблицу, которая показывает зависимость 
#медиальной цены и площади здания от числа комнат
melb_df.groupby('Rooms')[['Price', 'BuildingArea']].median()
# Out:
#            Price  BuildingArea
# Rooms
# 1       385000.0         107.0
# 2       690000.0         126.0
# 3       950000.0         126.0
# 4      1285000.0         142.0
# 5      1660000.0         176.0
# 6      1800000.0         126.0
# 7      1496000.0         216.5
# 8      1515000.0         126.0
# 10      900000.0         126.0

# %%
#Строим таблицу, в которой учитываем 
#не только число комнат, но и тип здания
melb_df.groupby(['Rooms', 'Type'])['Price'].mean()
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_3272\3929211266.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(['Rooms', 'Type'])['Price'].mean()
# Rooms  Type
# 1      house        8.668655e+05
#        townhouse    5.927045e+05
#        unit         3.899289e+05
# 2      house        1.017238e+06
#        townhouse    7.101585e+05
#        unit         6.104905e+05
# 3      house        1.109233e+06
#        townhouse    9.847087e+05
#        unit         8.505963e+05
# 4      house        1.462283e+06
#        townhouse    1.217092e+06
#        unit         1.037476e+06
# 5      house        1.877327e+06
#        townhouse    1.035000e+06
#        unit                  NaN
# 6      house        1.869508e+06
#        townhouse             NaN
# ...

# %%
#Применим метод unstack, чтобы из Series сделать сводную таблицу
melb_df.groupby(['Rooms', 'Type'])['Price'].mean().unstack()
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_3272\1871757643.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(['Rooms', 'Type'])['Price'].mean().unstack()
# Type          house     townhouse          unit
# Rooms
# 1      8.668655e+05  5.927045e+05  3.899289e+05
# 2      1.017238e+06  7.101585e+05  6.104905e+05
# 3      1.109233e+06  9.847087e+05  8.505963e+05
# 4      1.462283e+06  1.217092e+06  1.037476e+06
# 5      1.877327e+06  1.035000e+06           NaN
# 6      1.869508e+06           NaN  5.200000e+05
# 7      1.920700e+06           NaN           NaN
# 8      1.510286e+06           NaN  2.250000e+06
# 10     9.000000e+05           NaN           NaN

# %%
#Применим метод pivot_table() для построения сводной таблицы
melb_df.pivot_table(
    values='Price',
    index='Rooms',
    columns='Type',
    fill_value=0
).round()
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_3272\2312499911.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_df.pivot_table(
# Type       house  townhouse       unit
# Rooms
# 1       866866.0   592705.0   389929.0
# 2      1017238.0   710158.0   610491.0
# 3      1109233.0   984709.0   850596.0
# 4      1462283.0  1217092.0  1037476.0
# 5      1877327.0  1035000.0        0.0
# 6      1869508.0        0.0   520000.0
# 7      1920700.0        0.0        0.0
# 8      1510286.0        0.0  2250000.0
# 10      900000.0        0.0        0.0

# %%
#Построим таблицу для анализа 
#количества продаж в зависимости от дня недели
melb_df.pivot_table(
    values='Price',
    index='Regionname',
    columns='Weekend',
    aggfunc='count'
)
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_3272\1666349712.py:3: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_df.pivot_table(
# Weekend                        0     1
# Regionname
# Eastern Metropolitan         447  1024
# Eastern Victoria              13    40
# Northern Metropolitan       1258  2632
# Northern Victoria             11    30
# South-Eastern Metropolitan   123   327
# Southern Metropolitan       1534  3161
# Western Metropolitan         960  1988
# Western Victoria               8    24

# %%
#Построим таблицу с 2 аргументами
melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_3272\1454372207.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_df.pivot_table(
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_3272\1454372207.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_df.pivot_table(
#                            median                          mean              \
# Type                        house townhouse   unit        house   townhouse
# Regionname
# Eastern Metropolitan        674.0     233.5  203.0   717.422847  269.440678
# Eastern Victoria            843.0       0.0  230.0  3108.960000    0.000000
# ...

# %% [markdown]
# ### Многомерные свободные таблицы

# %%
#Построим таблицу с 2 признаками
melb_df.pivot_table(
    values='Price',
    index=['Method', 'Type'],
    columns='Regionname',
    aggfunc='median',
    fill_value=0
)
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_3272\1904824600.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_df.pivot_table(
# Regionname        Eastern Metropolitan  Eastern Victoria  \
# Method Type
# PI     house                 1244000.0          780000.0
#        townhouse              760000.0               0.0
#        unit                   650000.0               0.0
# S      house                 1127000.0          675000.0
#        townhouse              828000.0               0.0
#        unit                   645750.0          492000.0
# SA     house                  932500.0          950000.0
#        townhouse              807500.0               0.0
#        unit                        0.0               0.0
# SP     house                 1050000.0          672500.0
# ...

# %%
#Запишем таблицу которую мы создавали ранее в переменную
pivot = melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_3272\3142040833.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = melb_df.pivot_table(
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_3272\3142040833.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = melb_df.pivot_table(

# %%
#Выведем ее столбцы
pivot.columns
# Out:
# MultiIndex([('median',     'house'),
#             ('median', 'townhouse'),
#             ('median',      'unit'),
#             (  'mean',     'house'),
#             (  'mean', 'townhouse'),
#             (  'mean',      'unit')],
#            names=[None, 'Type'])

# %%
#Получим среднее значение площадей участка у типа здания unit
display(pivot['mean']['unit'])
# Out:
# Regionname
# Eastern Metropolitan          330.444444
# Eastern Victoria              295.333333
# Northern Metropolitan         495.026538
# Northern Victoria               0.000000
# South-Eastern Metropolitan    357.864865
# Southern Metropolitan         466.380245
# Western Metropolitan          557.637232
# Western Victoria                0.000000
# Name: unit, dtype: float64

# %%
#Фильтрация данных в сводных таблицах
mask = pivot['mean']['house'] < pivot['median']['house']
filtered_pivot = pivot[mask]
display(filtered_pivot)
# Out:
#                       median                        mean              \
# Type                   house townhouse  unit       house   townhouse
# Regionname
# Southern Metropolitan  586.0     246.0   0.0  569.643881  278.858824
# Western Metropolitan   531.0     198.0  62.0  507.883406  244.560669
#
#
# Type                         unit
# Regionname
# Southern Metropolitan  466.380245
# Western Metropolitan   557.637232

# %%
#Получить индексы из отфильтрованной таблицы
print(list(filtered_pivot.index))
# Out:
# ['Southern Metropolitan', 'Western Metropolitan']

# %%
#Пример создания вручную
import numpy as np
mser = pd.Series(
    np.random.rand(8),
	index=[['white','white','white','blue','blue','red','red','red'], 
           ['up','down','right','up','down','up','down','left']])
display(mser)
print(mser.index)
# Out:
# white  up       0.345918
#        down     0.377293
#        right    0.330804
# blue   up       0.100375
#        down     0.603054
# red    up       0.712092
#        down     0.014318
#        left     0.433994
# dtype: float64
# MultiIndex([('white',    'up'),
#             ('white',  'down'),
#             ('white', 'right'),
#             ( 'blue',    'up'),
#             ( 'blue',  'down'),
#             (  'red',    'up'),
#             (  'red',  'down'),
#             (  'red',  'left')],
#            )

# %%
mframe = pd.DataFrame(
    np.random.randn(16).reshape(4,4),
    index=[['white','white','red','red'], ['up','down','up','down']],
    columns=[['pen','pen','paper','paper'],[1,2,1,2]]
)
display(mframe)
# Out:
#                  pen               paper
#                    1         2         1         2
# white up   -1.202014 -0.138576  1.089279 -1.313606
#       down  0.116087 -0.295894 -2.538927 -0.622431
# red   up   -0.438956  0.224774  1.145733 -0.301455
#       down -1.085000 -0.366993  0.417042 -0.173258

# %% [markdown]
# ### Задание 4.2

# %%
melb_df.pivot_table(
    values='BuildingArea',
    index='Type',
    columns='Rooms',
    aggfunc='median',
    fill_value=0
)
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_3272\861002569.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_df.pivot_table(
# Rooms         1      2      3      4      5      6      7      8      10
# Type
# house      126.0  126.0  126.0  141.0  177.0  126.0  216.5  126.0  126.0
# townhouse   88.0  114.0  126.0  159.5  152.0    0.0    0.0    0.0    0.0
# unit        69.5  110.0  126.0  126.0    0.0  171.0    0.0  126.0    0.0

# %% [markdown]
# ### Задание 4.3

# %%
pivot = melb_df.pivot_table(
    values='Price',
    index='SellerG',
    columns='Type',
    aggfunc='median',
    fill_value=0
)
display(pivot)
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_3272\1542200060.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = melb_df.pivot_table(
# Type               house  townhouse      unit
# SellerG
# Alexkarbon     1036250.0   935000.0  560000.0
# Barry           830000.0   727500.0  502000.0
# Bells           692500.0   430500.0  457500.0
# Biggin         1151750.0   675000.0  548000.0
# Brad            875000.0   700000.0  465000.0
# Buckingham      830000.0   820000.0  553000.0
# Burnham         922500.0        0.0  305000.0
# Buxton         1323750.0  1030000.0  670000.0
# C21             836500.0   768750.0  625500.0
# Cayzer         1505000.0  1450000.0  707500.0
# Chisholm       1520000.0   950000.0  640000.0
# Collins        1566500.0   930000.0  592000.0
# Douglas         684000.0   500000.0  494500.0
# ...

# %%
pivot['unit'].sort_values(ascending=False)
# Out:
# SellerG
# Nick             900000.0
# Marshall         715000.0
# Cayzer           707500.0
# Kay              695000.0
# Noel             693250.0
# Buxton           670000.0
# Fletchers        653000.0
# Chisholm         640000.0
# Philip           636000.0
# RT               630000.0
# C21              625500.0
# RW               625500.0
# Moonee           622000.0
# O'Brien          618500.0
# Hodges           605500.0
# Eview            602000.0
# Woodards         600000.0
# Collins          592000.0
# Jellis           591750.0
# Purplebricks     582500.0
# Williams         577000.0
# hockingstuart    566000.0
# Alexkarbon       560000.0
# Miles            555000.0
# Buckingham       553000.0
# Gary             550000.0
# Biggin           548000.0
# Greg             547500.0
# McGrath          542500.0
# other            535000.0
# Nelson           530000.0
# HAR              518000.0
# McDonald         502500.0
# Barry            502000.0
# Harcourts        500000.0
# ...

# %% [markdown]
# ## Объединение DataFrame

# %% [markdown]
# ### Задание 5.2

# %%
movies = pd.read_csv('data/movies.csv')
ratings1 = pd.read_csv('data/ratings1.csv')
ratings2 = pd.read_csv('data/ratings2.csv')
dates = pd.read_csv('data/dates.csv')

# %%
display(movies.nunique())
# Out:
# movieId    9742
# title      9737
# genres      951
# dtype: int64

# %% [markdown]
# ### Задание 5.3

# %%
display(ratings1.nunique())
# Out:
# userId      274
# movieId    6219
# rating       10
# dtype: int64

# %% [markdown]
# ### Задание 5.4

# %%
display(dates)
# Out:
#                        date
# 0       2000-07-30 18:45:03
# 1       2000-07-30 18:20:47
# 2       2000-07-30 18:37:04
# 3       2000-07-30 19:03:35
# 4       2000-07-30 18:48:51
# ...                     ...
# 100831  2017-05-03 21:53:22
# 100832  2017-05-03 22:21:31
# 100833  2017-05-08 19:50:47
# 100834  2017-05-03 21:19:12
# 100835  2017-05-03 21:20:15
#
# [100836 rows x 1 columns]

# %%
dates['date'] = pd.to_datetime(dates['date'])

# %%
years_ratings = dates['date'].dt.year
years_ratings.value_counts()
# Out:
# date
# 2000    10061
# 2017     8198
# 2007     7114
# 2016     6703
# 2015     6616
# 2018     6418
# 1996     6040
# 2005     5813
# 2012     4656
# 2008     4351
# 2009     4158
# 2006     4059
# 2003     4014
# 2001     3922
# 2002     3478
# 2004     3279
# 1999     2439
# 2010     2301
# 1997     1916
# 2011     1690
# 2013     1664
# 2014     1439
# 1998      507
# Name: count, dtype: int64

# %%
display(dates)
# Out:
#                       date
# 0      2000-07-30 18:45:03
# 1      2000-07-30 18:20:47
# 2      2000-07-30 18:37:04
# 3      2000-07-30 19:03:35
# 4      2000-07-30 18:48:51
# ...                    ...
# 100831 2017-05-03 21:53:22
# 100832 2017-05-03 22:21:31
# 100833 2017-05-08 19:50:47
# 100834 2017-05-03 21:19:12
# 100835 2017-05-03 21:20:15
#
# [100836 rows x 1 columns]

# %% [markdown]
# ## concat

# %%
#Склеиваем (конкатенируем) 2 таблицы ratings1 и ratings2
ratings = pd.concat([ratings1, ratings2])
display(ratings)
# Out:
#        userId  movieId  rating
# 0           1        1     4.0
# 1           1        3     4.0
# 2           1        6     4.0
# 3           1       47     5.0
# 4           1       50     5.0
# ...       ...      ...     ...
# 60831     610   166534     4.0
# 60832     610   168248     5.0
# 60833     610   168250     5.0
# 60834     610   168252     5.0
# 60835     610   170875     3.0
#
# [100837 rows x 3 columns]

# %%
#Исправляем индексы
ratings = pd.concat(
    [ratings1,ratings2],
    ignore_index=True
)
display(ratings)
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100832     610   166534     4.0
# 100833     610   168248     5.0
# 100834     610   168250     5.0
# 100835     610   168252     5.0
# 100836     610   170875     3.0
#
# [100837 rows x 3 columns]

# %%
#Узнаем количество строк в ratings и dates
print('Число строк в таблице ratings: ', ratings.shape[0])
print('Число строк в таблице dates: ', dates.shape[0])
print(ratings.shape[0] == dates.shape[0])
# Out:
# Число строк в таблице ratings:  100837
# Число строк в таблице dates:  100836
# False

# %%
#Выведем последнюю и строку в ratings1 и первую в ratings2
display(ratings1.tail(1))
display(ratings2.head(1))
# Out:
#        userId  movieId  rating
# 40000     274     5621     2.0
#    userId  movieId  rating
# 0     274     5621     2.0

# %%
#Удаляем дубли из таблицы
ratings = ratings.drop_duplicates(ignore_index=True)
print('Число строк в таблице ratings: ', ratings.shape[0])
# Out:
# Число строк в таблице ratings:  100836

# %%
#Объединяем ratings и dates
ratings_dates = pd.concat([ratings, dates], axis=1)
display(ratings_dates.tail(7))
# Out:
#         userId  movieId  rating                date
# 100829     610   164179     5.0 2017-05-03 21:07:11
# 100830     610   166528     4.0 2017-05-04 06:29:25
# 100831     610   166534     4.0 2017-05-03 21:53:22
# 100832     610   168248     5.0 2017-05-03 22:21:31
# 100833     610   168250     5.0 2017-05-08 19:50:47
# 100834     610   168252     5.0 2017-05-03 21:19:12
# 100835     610   170875     3.0 2017-05-03 21:20:15

# %% [markdown]
# ### Метод объединения Join

# %%
#Попытка объединить 2 таблицы ratings_dates и movies
joined_false = ratings_dates.join(
    movies,
    rsuffix='_right',
    how='left'
)
display(joined_false)
# Out:
#         userId  movieId  rating                date  movieId_right  \
# 0            1        1     4.0 2000-07-30 18:45:03            1.0
# 1            1        3     4.0 2000-07-30 18:20:47            2.0
# 2            1        6     4.0 2000-07-30 18:37:04            3.0
# 3            1       47     5.0 2000-07-30 19:03:35            4.0
# 4            1       50     5.0 2000-07-30 18:48:51            5.0
# ...        ...      ...     ...                 ...            ...
# 100831     610   166534     4.0 2017-05-03 21:53:22            NaN
# 100832     610   168248     5.0 2017-05-03 22:21:31            NaN
# 100833     610   168250     5.0 2017-05-08 19:50:47            NaN
# 100834     610   168252     5.0 2017-05-03 21:19:12            NaN
# 100835     610   170875     3.0 2017-05-03 21:20:15            NaN
#
#                                      title  \
# 0                         Toy Story (1995)
# 1                           Jumanji (1995)
# ...

# %%
#Делаем правильное присоединение
joined = ratings_dates.join(
    movies.set_index('movieId'),
    on='movieId',
    how='left'
)
display(joined.head())
# Out:
#    userId  movieId  rating                date                        title  \
# 0       1        1     4.0 2000-07-30 18:45:03             Toy Story (1995)
# 1       1        3     4.0 2000-07-30 18:20:47      Grumpier Old Men (1995)
# 2       1        6     4.0 2000-07-30 18:37:04                  Heat (1995)
# 3       1       47     5.0 2000-07-30 19:03:35  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0 2000-07-30 18:48:51   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %% [markdown]
# ### Метод объединения MERGE

# %%
#Также соединим 2 таблицы, только другим методом
merged = ratings_dates.merge(
    movies,
    on='movieId',
    how='left'
)
display(merged.head())
# Out:
#    userId  movieId  rating                date                        title  \
# 0       1        1     4.0 2000-07-30 18:45:03             Toy Story (1995)
# 1       1        3     4.0 2000-07-30 18:20:47      Grumpier Old Men (1995)
# 2       1        6     4.0 2000-07-30 18:37:04                  Heat (1995)
# 3       1       47     5.0 2000-07-30 19:03:35  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0 2000-07-30 18:48:51   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
#Проверка, что число строк в ratings_dates == merged
print('Число строк в таблице ratings_dates: ', ratings_dates.shape[0])
print('Число строк в таблице merged: ', merged.shape[0])
print(ratings_dates.shape[0] == merged.shape[0])
# Out:
# Число строк в таблице ratings_dates:  100836
# Число строк в таблице merged:  100836
# True

# %%
#Ответ почему было выбрано left, а не outer
merged2 = ratings_dates.merge(
    movies,
    on='movieId',
    how='outer'
)
display(merged2.tail())
print('Число строк в merged2: ', merged2.shape[0])
# Out:
#         userId  movieId  rating                date  \
# 100849   184.0   193581     4.0 2018-09-16 14:44:42
# 100850   184.0   193583     3.5 2018-09-16 14:52:25
# 100851   184.0   193585     3.5 2018-09-16 14:56:45
# 100852   184.0   193587     3.5 2018-09-16 15:00:21
# 100853   331.0   193609     4.0 2018-09-17 04:13:26
#
#                                             title  \
# 100849  Black Butler: Book of the Atlantic (2017)
# 100850               No Game No Life: Zero (2017)
# 100851                               Flint (2017)
# 100852        Bungo Stray Dogs: Dead Apple (2018)
# 100853        Andrew Dice Clay: Dice Rules (1991)
#
#                                  genres
# 100849  Action|Animation|Comedy|Fantasy
# 100850         Animation|Comedy|Fantasy
# 100851                            Drama
# 100852                 Action|Animation
# 100853                           Comedy
# Число строк в merged2:  100854

# %%
#Рассмотрим метод merge с таблицами ratings1 и ratings2
merge_ratings = ratings1.merge(ratings2, how='outer')
print('Число строк в таблице merge_ratings: ', merge_ratings.shape[0])
display(merge_ratings)
# Out:
# Число строк в таблице merge_ratings:  100836
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100831     610   166534     4.0
# 100832     610   168248     5.0
# 100833     610   168250     5.0
# 100834     610   168252     5.0
# 100835     610   170875     3.0
#
# [100836 rows x 3 columns]

# %% [markdown]
# ### Задание 7.5

# %%
import pandas as pd

items_df = pd.DataFrame({
            'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 100132, 312394],
            'vendor': ['Samsung', 'LG', 'Apple', 'Apple', 'LG', 'Apple', 'Samsung', 'Samsung', 'LG', 'ZTE'],
            'stock_count': [54, 33, 122, 18, 102, 43, 77, 143, 60, 19]
        })

purchase_df = pd.DataFrame({
            'purchase_id': [101, 101, 101, 112, 121, 145, 145, 145, 145, 221],
            'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 103845, 100132],
            'price': [13900, 5330, 38200, 49990, 9890, 33000, 67500, 34500, 89900, 11400]
        })

# %%
merged = items_df.merge(
    purchase_df,
    on='item_id',
    how='inner'
)
display(merged)
# Out:
#    item_id   vendor  stock_count  purchase_id  price
# 0   417283  Samsung           54          101  13900
# 1   849734       LG           33          101   5330
# 2   132223    Apple          122          101  38200
# 3   573943    Apple           18          112  49990
# 4    19475       LG          102          121   9890
# 5  3294095    Apple           43          145  33000
# 6   382043  Samsung           77          145  67500
# 7   302948  Samsung          143          145  34500
# 8   100132       LG           60          221  11400

# %%
income = (merged['price']*merged['stock_count']).sum()
print(income)
# Out:
# 19729490

# %% [markdown]
# ## Итоговые задания

# %%
ratings_movies = pd.read_csv('data/ratings_movies.csv')
display(ratings_movies.head())
display(ratings_movies.tail())
# Out:
#    Unnamed: 0  userId  movieId  rating                 date  \
# 0           0       1        1     4.0  2000-07-30 18:45:03
# 1           1       1        3     4.0  2000-07-30 18:20:47
# 2           2       1        6     4.0  2000-07-30 18:37:04
# 3           3       1       47     5.0  2000-07-30 19:03:35
# 4           4       1       50     5.0  2000-07-30 18:48:51
#
#                          title                                       genres
# 0             Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1      Grumpier Old Men (1995)                               Comedy|Romance
# 2                  Heat (1995)                        Action|Crime|Thriller
# 3  Seven (a.k.a. Se7en) (1995)                             Mystery|Thriller
# 4   Usual Suspects, The (1995)                       Crime|Mystery|Thriller
#         Unnamed: 0  userId  movieId  rating                 date  \
# 100831      100831     610   166534     4.0  2017-05-03 21:53:22
# ...

# %%
#Для решения задач понадобится выделить из 
#признака title год выпуска фильма 
import re
def get_year_release(arg):
    #Находим все слова по шаблону '(DDDD)'
    candidates = re.findall(r'\(\d{4}\)', arg)
    #Проверяем число вхождений
    if len(candidates) > 0:
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        return None

# %% [markdown]
# ### Задание 8.1

# %%
ratings_movies['year_release'] = ratings_movies['title'].apply(get_year_release)
display(ratings_movies.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    100836 non-null  int64
#  1   userId        100836 non-null  int64
#  2   movieId       100836 non-null  int64
#  3   rating        100836 non-null  float64
#  4   date          100836 non-null  object
#  5   title         100836 non-null  object
#  6   genres        100836 non-null  object
#  7   year_release  100818 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 6.2+ MB
# None

# %% [markdown]
# ### Задание 8.2

# %%
mask= ratings_movies['year_release'] == 1999
ratings_movies[mask].groupby(by='title')['rating'].sum().sort_values()
# Out:
# title
# Bloodsport: The Dark Kumite (1999)                     0.5
# Chill Factor (1999)                                    1.0
# Source, The (1999)                                     1.0
# From Dusk Till Dawn 2: Texas Blood Money (1999)        1.0
# Julien Donkey-Boy (1999)                               1.0
#                                                      ...
# Green Mile, The (1999)                               460.5
# Sixth Sense, The (1999)                              697.0
# American Beauty (1999)                               827.5
# Fight Club (1999)                                    931.5
# Matrix, The (1999)                                  1165.5
# Name: rating, Length: 261, dtype: float64

# %% [markdown]
# ### Задание 8.3

# %%
mask= ratings_movies['year_release'] == 2010
ratings_movies[mask].groupby(by='genres')['rating'].sum().sort_values()
# Out:
# genres
# Action|Sci-Fi                                        1.0
# Action|Adventure|Horror                              1.5
# Action|Drama|Fantasy                                 1.5
# Crime|Romance                                        1.5
# Action|Children|Comedy                               2.0
#                                                    ...
# Comedy                                             255.0
# Drama|Mystery|Thriller                             303.5
# Action|Comedy                                      314.5
# Action|Crime|Drama|Mystery|Sci-Fi|Thriller|IMAX    581.5
# Drama                                              648.0
# Name: rating, Length: 119, dtype: float64

# %% [markdown]
# ### Задание 8.4

# %%
ratings_movies.groupby(by='userId')['genres'].nunique().sort_values(ascending=False)
# Out:
# userId
# 599    524
# 414    482
# 448    403
# 380    399
# 474    395
#       ...
# 494     15
# 578     15
# 214     13
# 85      13
# 245     13
# Name: genres, Length: 610, dtype: int64

# %% [markdown]
# ### Задание 8.5

# %%
ratings_movies.groupby('userId')['rating'].agg(
    ['count','mean']
).sort_values(by=['count', 'mean'],ascending=[True, False])
# Out:
#         count      mean
# userId
# 53         20  5.000000
# 595        20  4.200000
# 189        20  4.100000
# 569        20  4.000000
# 278        20  3.875000
# ...       ...       ...
# 274      1346  3.235884
# 448      1864  2.847371
# 474      2108  3.398956
# 599      2478  2.642050
# 414      2698  3.391957
#
# [610 rows x 2 columns]

# %% [markdown]
# ### Задание 8.6

# %%
mask1= ratings_movies['year_release'] == 2018
mean_rating_genres = ratings_movies[mask1].groupby('genres')['rating'].agg(
    ['mean', 'count']
).sort_values(by=['mean','count'], ascending=False)
display(mean_rating_genres)
mask2 = mean_rating_genres['count'] > 10
mean_rating_genres[mask2]
# Out:
#                                             mean  count
# genres
# Adventure|Comedy|Fantasy                4.500000      1
# Adventure|Thriller                      4.500000      1
# Comedy|Fantasy|Sci-Fi                   4.500000      1
# Comedy|Romance                          4.500000      1
# Documentary                             4.000000      2
# Action|Comedy|Crime|Horror              4.000000      1
# Action|Crime|Drama|Thriller             4.000000      1
# Action|Adventure|Sci-Fi                 3.928571     14
# Action|Adventure|Children|Sci-Fi        3.900000      5
# Action|Comedy|Sci-Fi                    3.875000     12
# Adventure|Mystery|Sci-Fi|Thriller       3.833333      3
# Action|Adventure|Thriller               3.750000      2
# Action|Adventure|Comedy|Fantasy|Sci-Fi  3.666667      3
# Animation|Comedy                        3.500000      5
# Action|Animation                        3.500000      1
# Action|Mystery|Sci-Fi|Thriller          3.500000      1
# ...

# %% [markdown]
# ### Задание 8.7

# %% [markdown]
# #### Подготовка

# %%
ratings_movies['date'] = pd.to_datetime(ratings_movies['date'])
ratings_movies['year_rating'] = ratings_movies['date'].dt.year
display(ratings_movies)
# Out:
#         Unnamed: 0  userId  movieId  rating                date  \
# 0                0       1        1     4.0 2000-07-30 18:45:03
# 1                1       1        3     4.0 2000-07-30 18:20:47
# 2                2       1        6     4.0 2000-07-30 18:37:04
# 3                3       1       47     5.0 2000-07-30 19:03:35
# 4                4       1       50     5.0 2000-07-30 18:48:51
# ...            ...     ...      ...     ...                 ...
# 100831      100831     610   166534     4.0 2017-05-03 21:53:22
# 100832      100832     610   168248     5.0 2017-05-03 22:21:31
# 100833      100833     610   168250     5.0 2017-05-08 19:50:47
# 100834      100834     610   168252     5.0 2017-05-03 21:19:12
# 100835      100835     610   170875     3.0 2017-05-03 21:20:15
#
#                                  title  \
# 0                     Toy Story (1995)
# 1              Grumpier Old Men (1995)
# 2                          Heat (1995)
# ...

# %% [markdown]
# #### Первая часть

# %%
mask1 = (ratings_movies['year_rating'] >= 1996)&(ratings_movies['year_rating'] <= 2018)
mask2 = ratings_movies['genres'] == 'Action|Adventure'
ratings_movies[mask1&mask2].groupby(['genres', 'year_rating'])['rating'].mean().min()
# Out:
# np.float64(3.2777777777777777)

# %% [markdown]
# #### Вторая часть

# %%
mask1 = ratings_movies['genres'] == 'Action|Adventure|Animation|Children|Comedy|IMAX'
ratings_movies[mask1].groupby(['genres', 'year_rating'])['rating'].mean().sort_values(ascending=False)
# Out:
# genres                                           year_rating
# Action|Adventure|Animation|Children|Comedy|IMAX  2013           5.000000
#                                                  2018           3.700000
#                                                  2016           3.666667
#                                                  2012           3.550000
#                                                  2014           3.500000
#                                                  2010           3.500000
#                                                  2015           3.375000
#                                                  2009           3.250000
#                                                  2017           1.000000
# Name: rating, dtype: float64

# %% [markdown]
# #### Третья часть

# %%
mask1 = ratings_movies['year_rating'] == 2018
mask2 = ratings_movies['genres'] == 'Animation|Children|Mystery'
ratings_movies[mask1&mask2].groupby(['genres', 'year_rating'])['rating'].mean().sort_values(ascending=False)
# Out:
# genres                      year_rating
# Animation|Children|Mystery  2018           5.0
# Name: rating, dtype: float64

# %% [markdown]
# #### Четвертая часть

# %%
mask1 = (ratings_movies['year_release'] >= 1996)&(ratings_movies['year_release'] <= 2018)
mask2 = ratings_movies['genres'] == 'Comedy'
ratings_movies[mask1&mask2].groupby(['genres', 'year_rating'])['rating'].mean().sort_values(ascending=False)
# Out:
# genres  year_rating
# Comedy  2012           3.422680
#         1996           3.420290
#         1997           3.351145
#         2001           3.345912
#         2013           3.333333
#         2004           3.293578
#         2014           3.282353
#         2016           3.263359
#         2008           3.258427
#         2018           3.244361
#         1999           3.232877
#         2006           3.195455
#         2009           3.176829
#         2011           3.104167
#         2002           3.070000
#         2003           2.971631
#         2015           2.936330
#         2000           2.935849
#         2010           2.935484
#         2005           2.821782
#         1998           2.812500
#         2007           2.769679
#         2017           2.752874
# Name: rating, dtype: float64

# %% [markdown]
# ### Задания 8.8 - 8.10

# %%
orders = pd.read_csv('data/orders.csv', sep=';')
display(orders.head())
display(orders.tail())
display(orders.info())
orders['Product_ID'] = orders['ID товара']
# Out:
#          Дата создания  Order ID  ID Покупателя                    Статус  \
# 0  09.11.2019 21:55:51         9             10  Принят, ожидается оплата
# 1  09.11.2019 15:05:57         8              9  Принят, ожидается оплата
# 2  09.11.2019 15:05:57         8              9  Принят, ожидается оплата
# 3  09.11.2019 12:50:07         7              8  Принят, ожидается оплата
# 4  09.11.2019 12:00:00         6              1  Принят, ожидается оплата
#
#   Оплачен Отменен Отгружен  ID товара  Количество
# 0     Нет     Нет      Нет        103           5
# 1     Нет     Нет      Нет         86         100
# 2     Нет     Нет      Нет        104          10
# 3     Нет     Нет      Нет        104           7
# 4     Нет     Нет      Нет        104           5
#           Дата создания  Order ID  ID Покупателя  \
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# ...

# %%
products = pd.read_csv('data/products.csv', sep=';')
display(products.head())
display(products.tail())
display(products.info())
# Out:
#    Product_ID                      Name  Price CURRENCY
# 0          47      Шатны Полосатый рейс   2999      RUR
# 1          51  Платье Аленький цветочек   4999      RUR
# 2          53    Штаны Цветочная Поляна   4999      RUR
# 3          71       Платье Ночная Жизнь   7999      RUR
# 4          74  Платье Ночная Жизнь XXXL   8999      RUR
#     Product_ID                                   Name  Price CURRENCY
# 9          124                   Носки беговые Camino    999      RUR
# 10         137              Гольфы детские Снегурочка     99      RUR
# 11         138               Гольфы детские Питер Пен     99      RUR
# 12         139                       Сумка для носков    500      RUR
# 13         140  Товар, которому не придумано название      1      RUR
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
# ...

# %%
orders_products = orders.merge(
    products,
    on='Product_ID',
    how='left' 
)
display(orders_products)
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
# ...

# %%
mask= ((orders_products['Статус'] == 'Оплачен, формируется к отправке')|
(orders_products['Статус'] == 'Выполнен'))
orders_products[mask].groupby('ID Покупателя')['Price'].agg(['count', 'sum']).sort_values(by='sum', ascending=False)
# Out:
#                count      sum
# ID Покупателя
# 7                  4  17096.0
# 5                  3  13043.0
# 8                  2    448.0
# 1                  0      0.0
